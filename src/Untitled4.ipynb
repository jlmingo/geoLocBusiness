# %%
import pandas as pd
import folium
from folium import Marker

# %%
df= pd.read_json("../input/df_austin.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a1d24ed679bd> in <module>
# ----> 1 df= pd.read_json("../input/df_austin.json")
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ...

# %%
df.head()

# %%
# df["Airport_longitude"] = df.Coord_Closest_Airport.apply(lambda x: x[0])
df.dtypes
# Out:
# Unnamed: 0                   int64
# Unnamed: 0.1                 int64
# _id                         object
# name                        object
# permalink                   object
# crunchbase_url              object
# homepage_url                object
# blog_url                    object
# blog_feed_url               object
# twitter_username            object
# category_code               object
# number_of_employees        float64
# founded_year               float64
# deadpooled_year            float64
# tag_list                    object
# alias_list                 float64
# email_address               object
# phone_number                object
# description                 object
# created_at                  object
# updated_at                  object
# overview                    object
# image                       object
# products                    object
# relationships               object
# competitions                object
# providerships               object
# ...

# %%
df
# Out:
#    Unnamed: 0  Unnamed: 0.1                       _id                name  \
# 0           1           890  52cdef7c4bab8bd67529809a             Shangby
# 1           3          1490  52cdef7c4bab8bd6752982f7        CyberRentals
# 2           4          1492  52cdef7c4bab8bd6752982f9           TripHomes
# 3           5          1688  52cdef7c4bab8bd6752983ba          MessageOne
# 4           7          2571  52cdef7c4bab8bd67529873f   Absolute Software
# 5          23         10563  52cdef7e4bab8bd67529ad8b          NetStreams
# 6          27         12856  52cdef7e4bab8bd67529b8c0          Infochimps
# 7          29         13694  52cdef7e4bab8bd67529bcf8           AppUseful
# 8          31         14406  52cdef7f4bab8bd67529c01d           Quintiles
# 9          34         15124  52cdef7f4bab8bd67529c39e  Pelorus Technology
#
#             permalink                                     crunchbase_url  \
# 0             shangby          http://www.crunchbase.com/company/shangby
# ...

# %%
df.Closest_Airport[0]
# Out:
# '[{\'_id\': ObjectId(\'5dd675f33b0eaf5b22d77d95\'), \'name\': "Austin-Bergstrom Int\'l", \'geoJSON\': {\'type\': \'Point\', \'coordinates\': [-97.6668367646, 30.2021081921]}}]'

# %%
def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')

# %%
m = folium.Map(location=[-97.6668367646,30.2021081921], zoom_start=11)
# HeatMap(data=releases[['LATITUDE', 'LONGITUDE']], radius=15).add_to(m)
for idx, row in df.iterrows():
    Marker([row['latitude'], row['longitude']], icon=folium.Icon(icon='info-sign',color='blue')).add_to(m)
    Marker(-[row['Coord_Closest_Airport'][0], [row['Coord_Closest_Airport'][1]], icon=folium.Icon(icon='cloud',color='red')).add_to(m)
# Plot each polygon on the map
# GeoJson(two_mile_buffer.to_crs(epsg=4326)).add_to(m)

# Show the map
embed_map(m, 'm1.html')
# Out:
#   File "<ipython-input-13-12c463329747>", line 5
#     Marker(-[row['Coord_Closest_Airport'][0], [row['Coord_Closest_Airport'][1]], icon=folium.Icon(icon='cloud',color='red')).add_to(m)
#                                                                                      ^
# SyntaxError: invalid syntax
