# %%
import pandas as pd
from functions import getLoc

df_techCos = pd.read_csv("../input/clean_df_companies.csv")
df_techCos[(df_techCos["Tech/Other"] == "Tech") & (df_techCos["total_money_raised"] >= 1000000)]
df_techCos["geoJSON"] = df_techCos.apply(
    lambda x: getLoc(x.longitude, x.latitude), axis=1)
df_techCos.drop(df_techCos[(df_techCos.longitude.isnull() == True) | (
    df_techCos.latitude.isnull() == True)].index, inplace=True)
df_techCos.to_json("../input/oldCos.json", orient='records')
print("df_techCos.json exported successfully")

# %%
# Out:
#        Unnamed: 0                       _id                     name  \
# 1               1  52cdef7c4bab8bd675297d91                     Geni
# 4               4  52cdef7c4bab8bd675297d8d                     Digg
# 5               5  52cdef7c4bab8bd675297d96                   Gizmoz
# 6               6  52cdef7c4bab8bd675297d95              StumbleUpon
# 7               8  52cdef7c4bab8bd675297d97                   Scribd
# ...           ...                       ...                      ...
# 10148       15828  52cdef7f4bab8bd67529c6de                 Cantimer
# 10149       15829  52cdef7f4bab8bd67529c6e0  Celestial Semiconductor
# 10152       15832  52cdef7f4bab8bd67529c6e3          InSound Medical
# 10153       15833  52cdef7f4bab8bd67529c6e1                 Purfresh
# 10154       15834  52cdef7f4bab8bd67529c6e4                   Getyoo
#
#                      permalink  \
# 1                         geni
# 4                         digg
# 5                       gizmoz
# 6                  stumbleupon
# 7                       scribd
# ...                        ...
# 10148                 cantimer
# 10149  celestial-semiconductor
# 10152          insound-medical
# 10153                 purfresh
# 10154                   getyoo
#
#                                           crunchbase_url  \
# 1                 http://www.crunchbase.com/company/geni
# 4                 http://www.crunchbase.com/company/digg
# 5               http://www.crunchbase.com/company/gizmoz
# 6          http://www.crunchbase.com/company/stumbleupon
# 7               http://www.crunchbase.com/company/scribd
# ...                                                  ...
# 10148         http://www.crunchbase.com/company/cantimer
# 10149  http://www.crunchbase.com/company/celestial-se...
# 10152  http://www.crunchbase.com/company/insound-medical
# 10153         http://www.crunchbase.com/company/purfresh
# 10154           http://www.crunchbase.com/company/getyoo
#
#                         homepage_url                          blog_url  \
# 1                http://www.geni.com              http://blog.geni.com
# 4                http://www.digg.com             http://blog.digg.com/
# 5                  http://gizmoz.com                               NaN
# 6         http://www.stumbleupon.com   http://www.stumbleupon.com/blog
# 7                  http://scribd.com           http://blog.scribd.com/
# ...                              ...                               ...
# 10148        http://www.cantimer.com                               NaN
# 10149    http://www.celestialsemi.cn                               NaN
# 10152  http://www.insoundmedical.com                               NaN
# 10153        http://www.purfresh.com  http://info.purfresh.com/PurTalk
# 10154          http://www.getyoo.com         http://getyoo.tumblr.com/
#
#                          blog_feed_url twitter_username  category_code  ...  \
# 1       http://blog.geni.com/index.rdf             geni            web  ...
# 4      http://blog.digg.com/?feed=rss2             digg           news  ...
# 5                                  NaN              NaN            web  ...
# 6                                  NaN      stumbleupon            web  ...
# 7         http://blog.scribd.com/feed/           scribd           news  ...
# ...                                ...              ...            ...  ...
# 10148                              NaN              NaN            NaN  ...
# 10149                              NaN              NaN  semiconductor  ...
# 10152                              NaN              NaN        biotech  ...
# 10153                              NaN     Purfresh_Inc      cleantech  ...
# 10154     http://getyoo.tumblr.com/rss           getyoo         mobile  ...
#
#        description.1                          address1   address2 zip_code  \
# 1       Headquarters              9229 W. Sunset Blvd.        NaN    90069
# 4                NaN                135 Mississippi St        NaN    94107
# 5                NaN                               NaN        NaN      NaN
# 6                NaN                               NaN        NaN      NaN
# 7                 HQ                 539 Bryant Street        NaN    94107
# ...              ...                               ...        ...      ...
# 10148            NaN                  3700 Haven Court        NaN    94025
# 10149            NaN  2635 North 1st Street, Suite 150        NaN    95134
# 10152            NaN                39660 Eureka Drive        NaN    94560
# 10153             HQ                 1350 Willow Road,  Suite 102    94025
# 10154             HQ             Rue des Tanneurs, 60a        NaN     1000
#
#                  city state_code country_code   latitude   longitude  \
# 1      West Hollywood         CA          USA  34.090368 -118.393064
# 4       San Francisco         CA          USA  37.764726 -122.394523
# 5          Menlo Park         CA          USA  37.484130 -122.169472
# 6       San Francisco         CA          USA  37.775196 -122.419204
# 7       San Francisco         CA          USA  37.789634 -122.404052
# ...               ...        ...          ...        ...         ...
# 10148      Menlo Park         CA          USA  37.484616 -122.181753
# 10149        San Jose         CA          USA  37.386417 -121.929170
# 10152          Newark         CA          USA  37.512038 -121.998513
# 10153      Menlo Park         CA          USA  37.477008 -122.151599
# 10154        Brussels        NaN          BEL  50.839970    4.346472
#
#       Tech/Other
# 1           Tech
# 4           Tech
# 5           Tech
# 6           Tech
# 7           Tech
# ...          ...
# 10148       Tech
# 10149       Tech
# 10152       Tech
# 10153       Tech
# 10154       Tech
#
# [3076 rows x 52 columns]

# %%
df_techCos[df_techCos["total_money_raised"] > 1000000].total_money_raised
# Out:
# 1        16500000
# 4        45000000
# 5        18100000
# 6        18500000
# 7        25800000
#            ...
# 10148     2000000
# 10149     2000000
# 10152    11000000
# 10153    62700000
# 10154     1130000
# Name: total_money_raised, Length: 3001, dtype: int64
