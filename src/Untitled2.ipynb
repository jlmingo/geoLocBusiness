# %%
import pandas as pd
from functions import connectCollection, searchNear

df_filtered = pd.read_csv("../input/clean_df_companies.csv")

# Import airports and querying them

db, airports = connectCollection('companies', 'airports')

df_filtered["Closest_Airport"] = df_filtered.apply(lambda x: searchNear(
    x.longitude, x.latitude, airports, 30000), axis=1)
df_filtered["Closest_Airport"] = df_filtered.Closest_Airport.apply(lambda x: list(x))
df_filtered = df_filtered[df_filtered['Closest_Airport'].astype(bool)]

# Import old companies around

db, oldcos = connectCollection('companies', 'oldCos')

df_filtered["Closest_oldCo"] = df_filtered.apply(lambda x: searchNear(
    x.longitude, x.latitude, oldcos, 2000), axis=1)
df_filtered["Closest_oldCo"] = df_filtered.Closest_oldCo.apply(lambda x: list(x))

# %%
df_filtered
# Out:
#        Unnamed: 0                       _id                   name  \
# 0               0  52cdef7c4bab8bd675297d90                Postini
# 1               1  52cdef7c4bab8bd675297d91                   Geni
# 2               2  52cdef7c4bab8bd675297d92                Flektor
# 3               3  52cdef7c4bab8bd675297d93  Fox Interactive Media
# 4               4  52cdef7c4bab8bd675297d8d                   Digg
# ...           ...                       ...                    ...
# 10159       15841  52cdef7f4bab8bd67529c6f3                   QSGI
# 10160       15842  52cdef7f4bab8bd67529c6f1          Willdan Group
# 10162       15845  52cdef7f4bab8bd67529c6f7             AfterLogic
# 10163       15846  52cdef7f4bab8bd67529c6f9    EnteGreat Solutions
# 10164       15847  52cdef7f4bab8bd67529c6fa              EnteGreat
#
#                    permalink  \
# 0                    postini
# 1                       geni
# 2                    flektor
# 3      fox-interactive-media
# 4                       digg
# ...                      ...
# 10159                   qsgi
# 10160          willdan-group
# 10162             afterlogic
# 10163    entegreat-solutions
# 10164              entegreat
#
#                                           crunchbase_url  \
# 0              http://www.crunchbase.com/company/postini
# 1                 http://www.crunchbase.com/company/geni
# 2              http://www.crunchbase.com/company/flektor
# 3      http://www.crunchbase.com/company/fox-interact...
# 4                 http://www.crunchbase.com/company/digg
# ...                                                  ...
# 10159             http://www.crunchbase.com/company/qsgi
# 10160    http://www.crunchbase.com/company/willdan-group
# 10162       http://www.crunchbase.com/company/afterlogic
# 10163  http://www.crunchbase.com/company/entegreat-so...
# 10164        http://www.crunchbase.com/company/entegreat
#
#                     homepage_url                     blog_url  \
# 0             http://postini.com                          NaN
# 1            http://www.geni.com         http://blog.geni.com
# 2         http://www.flektor.com  http://www.flektor-blog.com
# 3        http://www.newscorp.com                          NaN
# 4            http://www.digg.com        http://blog.digg.com/
# ...                          ...                          ...
# 10159        http://www.qsgi.com                          NaN
# 10160     http://www.willdan.com                          NaN
# 10162  http://www.afterlogic.com                          NaN
# 10163                        NaN                          NaN
# 10164   http://www.entegreat.com                          NaN
#
#                                            blog_feed_url twitter_username  \
# 0                                                    NaN              NaN
# 1                         http://blog.geni.com/index.rdf             geni
# 2      http://www.flektor-blog.com/video_editing_soft...              NaN
# 3                                                    NaN       twitterapi
# 4                        http://blog.digg.com/?feed=rss2             digg
# ...                                                  ...              ...
# 10159                                                NaN        eCigsQSGI
# 10160                                                NaN              NaN
# 10162                                                NaN       afterlogic
# 10163                                                NaN              NaN
# 10164                                                NaN              NaN
#
#       category_code  ...   address2    zip_code            city state_code  \
# 0               web  ...        NaN       94070      San Carlos         CA
# 1               web  ...        NaN       90069  West Hollywood         CA
# 2       games_video  ...        NaN       90232     Culver City         CA
# 3               web  ...        NaN       90210   Beverly Hills         CA
# 4              news  ...        NaN       94107   San Francisco         CA
# ...             ...  ...        ...         ...             ...        ...
# 10159      software  ...        NaN       33480      Palm Beach         FL
# 10160         other  ...  Suite 300  92806-5909         Anaheim         CA
# 10162      software  ...        NaN       07039      Livingston         NJ
# 10163      software  ...        NaN         NaN      Birmingham         AL
# 10164    enterprise  ...  Suite 200  35243-4204      Birmingham         AL
#
#       country_code   latitude   longitude Tech/Other  \
# 0              USA  37.506885 -122.247573       Tech
# 1              USA  34.090368 -118.393064       Tech
# 2              USA  34.025958 -118.379768       Tech
# 3              USA  34.076179 -118.394170       Tech
# 4              USA  37.764726 -122.394523      Other
# ...            ...        ...         ...        ...
# 10159          USA  26.705331  -80.041395       Tech
# 10160          USA  33.806525 -117.882314      Other
# 10162          USA  40.793024  -74.323554       Tech
# 10163          USA  33.518885  -86.816068       Tech
# 10164          USA  33.407786  -86.761302      Other
#
#                                          Closest_Airport  \
# 0      [{'_id': 5dd675f33b0eaf5b22d77ec3, 'name': 'Sa...
# 1      [{'_id': 5dd675f33b0eaf5b22d77eb9, 'name': 'Lo...
# 2      [{'_id': 5dd675f33b0eaf5b22d77eb9, 'name': 'Lo...
# 3      [{'_id': 5dd675f33b0eaf5b22d77eb9, 'name': 'Lo...
# 4      [{'_id': 5dd675f33b0eaf5b22d77ec3, 'name': 'Sa...
# ...                                                  ...
# 10159  [{'_id': 5dd675f33b0eaf5b22d77d48, 'name': 'Pa...
# 10160  [{'_id': 5dd675f33b0eaf5b22d77dae, 'name': 'Jo...
# 10162  [{'_id': 5dd675f33b0eaf5b22d77eb2, 'name': 'Ne...
# 10163  [{'_id': 5dd675f33b0eaf5b22d77b98, 'name': 'Bi...
# 10164  [{'_id': 5dd675f33b0eaf5b22d77b98, 'name': 'Bi...
#
#                                            Closest_oldCo
# 0      [{'_id': '52cdef7c4bab8bd675297d90', 'Unnamed:...
# 1      [{'_id': '52cdef7c4bab8bd675297d91', 'Unnamed:...
# 2      [{'_id': '52cdef7c4bab8bd675298475', 'Unnamed:...
# 3      [{'_id': '52cdef7c4bab8bd675297d93', 'Unnamed:...
# 4      [{'_id': '52cdef7c4bab8bd675297d8d', 'Unnamed:...
# ...                                                  ...
# 10159  [{'_id': '52cdef7f4bab8bd67529c6f3', 'Unnamed:...
# 10160                                                 []
# 10162  [{'_id': '52cdef7f4bab8bd67529c6f7', 'Unnamed:...
# 10163                                                 []
# 10164  [{'_id': '52cdef7f4bab8bd67529c6fa', 'Unnamed:...
#
# [8087 rows x 54 columns]

# %%
df_filtered[df_filtered['Closest_oldCo'].astype(bool) == False]
# Out:
#        Unnamed: 0                       _id                 name  \
# 26             30  52cdef7c4bab8bd675297da7              AddThis
# 86            104  52cdef7c4bab8bd675297dba               Google
# 89            107  52cdef7c4bab8bd675297dba               Google
# 92            111  52cdef7c4bab8bd675297dba               Google
# 93            112  52cdef7c4bab8bd675297dba               Google
# ...           ...                       ...                  ...
# 10107       15769  52cdef7f4bab8bd67529c694           Fictionaut
# 10143       15817  52cdef7f4bab8bd67529c6d5             SEO Sumo
# 10150       15830  52cdef7f4bab8bd67529c6e2            MyChances
# 10160       15842  52cdef7f4bab8bd67529c6f1        Willdan Group
# 10163       15846  52cdef7f4bab8bd67529c6f9  EnteGreat Solutions
#
#                  permalink                                     crunchbase_url  \
# 26                 addthis          http://www.crunchbase.com/company/addthis
# 86                  google           http://www.crunchbase.com/company/google
# 89                  google           http://www.crunchbase.com/company/google
# 92                  google           http://www.crunchbase.com/company/google
# 93                  google           http://www.crunchbase.com/company/google
# ...                    ...                                                ...
# 10107           fictionaut       http://www.crunchbase.com/company/fictionaut
# 10143             seo-sumo         http://www.crunchbase.com/company/seo-sumo
# 10150            mychances        http://www.crunchbase.com/company/mychances
# 10160        willdan-group    http://www.crunchbase.com/company/willdan-group
# 10163  entegreat-solutions  http://www.crunchbase.com/company/entegreat-so...
#
#                    homepage_url                        blog_url  \
# 26       http://www.addthis.com         http://addthis.com/blog
# 86            http://google.com  http://googleblog.blogspot.com
# 89            http://google.com  http://googleblog.blogspot.com
# 92            http://google.com  http://googleblog.blogspot.com
# 93            http://google.com  http://googleblog.blogspot.com
# ...                         ...                             ...
# 10107     http://fictionaut.com      http://blog.fictionaut.com
# 10143    http://www.seosumo.com                             NaN
# 10150  http://www.mychances.net  http://www.mychances.net/blog/
# 10160    http://www.willdan.com                             NaN
# 10163                       NaN                             NaN
#
#                                            blog_feed_url twitter_username  \
# 26                          http://addthis.com/blog/feed          addthis
# 86     http://googleblog.blogspot.com/feeds/posts/def...           google
# 89     http://googleblog.blogspot.com/feeds/posts/def...           google
# 92     http://googleblog.blogspot.com/feeds/posts/def...           google
# 93     http://googleblog.blogspot.com/feeds/posts/def...           google
# ...                                                  ...              ...
# 10107                   http://blog.fictionaut.com/feed/       fictionaut
# 10143                                                NaN          seosumo
# 10150                http://www.mychances.net/blog/feed/        mychances
# 10160                                                NaN              NaN
# 10163                                                NaN              NaN
#
#           category_code  ...     address2    zip_code        city state_code  \
# 26          advertising  ...       Unit A       48084        Troy         MI
# 86               search  ...    Suite 120       75019     Coppell         TX
# 89               search  ...          NaN       48009  Birmingham         MI
# 92               search  ...    2nd floor       85281       Tempe         AZ
# 93               search  ...  Lower Level       15213  Pittsburgh         PA
# ...                 ...  ...          ...         ...         ...        ...
# 10107       games_video  ...          NaN       77098     Houston         TX
# 10143  public_relations  ...          NaN       33155       Miami         FL
# 10150        consulting  ...          NaN       89511        Reno         NV
# 10160             other  ...    Suite 300  92806-5909     Anaheim         CA
# 10163          software  ...          NaN         NaN  Birmingham         AL
#
#       country_code   latitude   longitude Tech/Other  \
# 26             USA  42.557958  -83.167884      Other
# 86             USA  32.981465  -97.018196      Other
# 89             USA  42.547807  -83.215498      Other
# 92             USA  33.411898 -111.926263      Other
# 93             USA  40.444528  -79.946269      Other
# ...            ...        ...         ...        ...
# 10107          USA  29.735462  -95.413243       Tech
# 10143          USA  25.723408  -80.306331      Other
# 10150          USA  39.394564 -119.812079      Other
# 10160          USA  33.806525 -117.882314      Other
# 10163          USA  33.518885  -86.816068       Tech
#
#                                          Closest_Airport Closest_oldCo
# 26     [{'_id': 5dd675f33b0eaf5b22d77c91, 'name': 'De...            []
# 86     [{'_id': 5dd675f33b0eaf5b22d77ebe, 'name': 'Da...            []
# 89     [{'_id': 5dd675f33b0eaf5b22d77c91, 'name': 'De...            []
# 92     [{'_id': 5dd675f33b0eaf5b22d77e90, 'name': 'Sk...            []
# 93     [{'_id': 5dd675f33b0eaf5b22d77d4f, 'name': 'Gr...            []
# ...                                                  ...           ...
# 10107  [{'_id': 5dd675f33b0eaf5b22d77eb4, 'name': 'Ge...            []
# 10143  [{'_id': 5dd675f33b0eaf5b22d77e1d, 'name': 'Mi...            []
# 10150  [{'_id': 5dd675f33b0eaf5b22d77cc8, 'name': 'Re...            []
# 10160  [{'_id': 5dd675f33b0eaf5b22d77dae, 'name': 'Jo...            []
# 10163  [{'_id': 5dd675f33b0eaf5b22d77b98, 'name': 'Bi...            []
#
# [475 rows x 54 columns]
