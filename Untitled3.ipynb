# %%
from pymongo import MongoClient
import pandas as pd
import re
import geopandas as gpd

#Import MongoDB collection and create DataFrame

def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

db, coll = connectCollection('companies','companies')

pipeline = [
    { "$unwind": "$offices"},    
 ]

results = list(coll.aggregate(pipeline))
df = pd.DataFrame(results)
print("Collection imported succesfully, DataFrame Generated")
#Drop deadpooled companies

df = df[df.deadpooled_year.isnull()]
df.reset_index(inplace=True, drop= True)

#Unwind Office column
df = pd.concat([df.drop(['offices'], axis=1), df['offices'].apply(pd.Series)], axis=1)

#Re-classifying categories into Tech/Other
tech = ["web", "games_video", "mobile", "social", "photo_video", "network_hosting", "software", "ecommerce", "hardware", "semiconductor", "analytics", "biotech", "cleantech", "nanotech"]
df["Tech/Other"] = df["category_code"].apply(lambda x: "Tech" if x in tech else "Other")

#Clean money raised column

def moneyRaise(value):
    dicc_coin = {'CAD': 0.76,'RUB': 0.016, 'EUR': 1.11, 'GBP': 1.29}
    values_money = {'K':1000, 'M':1000000, 'B': 100000000000}
    value_number = float(re.search('[+-]?([0-9]*[.])?[0-9]+', value)[0])
    if value.endswith('B'):
        exchange = value_number*(values_money['B'])
    elif value.endswith('K[k]'):
        exchange = value_number*(values_money['K'])
    elif value.endswith('M'):
        exchange = value_number*(values_money['M'])
    elif value.startswith("C"):
        exchange =  value_number*(dicc_coin['CAD'])
    elif value.startswith("$"):
        exchange =  value_number
    elif value.startswith("€"):
        exchange = value_number*(dicc_coin['EUR'])
    elif value.startswith("£"):
        exchange = value_number*(dicc_coin['GBP'])
    elif value.startswith("r"):
        exchange = value_number*(dicc_coin['RUB'])
    else:
        exchange = value_number
    return int(exchange)

df.total_money_raised = df.total_money_raised.apply(moneyRaise)

drop_rows = df[((df.latitude.isnull() == True) | (df.longitude.isnull() == True))].index
df.drop(drop_rows, inplace=True)
df.to_csv("./Input/clean_df_companies.csv")
print("Cleaned DataFrame successfully exported to csv")

#Importing airports geoDataFrame

gdf_airports = gpd.read_file("./Input/ne_10m_airports/ne_10m_airports.shp")
print("Airports shp file imported.")

#Function for creating GeoJSON column

def getLocation(gdf):
    long = gdf.x
    lat = gdf.y
    loc = {
        'type':'Point',
        'coordinates':[long, lat]
    }
    return loc

#Convert df in geoDataFrame

def df_to_gdf(dataframe):
    gdf = gpd.GeoDataFrame(dataframe, geometry=gpd.points_from_xy(dataframe.longitude, dataframe.latitude))
    gdf.crs = {'init' :'epsg:4326'}
    gdf.reset_index(drop=True, inplace=True)
    return gdf

gdf_master = df_to_gdf(df)

gdf_airports["geoJSON"] = gdf_airports.geometry.apply(lambda x: getLocation(x))

#Exporting to JSON
df_master = pd.DataFrame(gdf_master)
df_airports = pd.DataFrame(gdf_airports)
df_airports.drop(df_airports.columns[1], axis=1, inplace=True)
# df_airports.to_json("airports.json", orient='records')
# print("JSON file generated.")
# Out:
# Collection imported succesfully, DataFrame Generated
# Cleaned DataFrame successfully exported to csv
# Airports shp file imported.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-2-b5631d0c37c3> in <module>
#      98 df_airports = pd.DataFrame(gdf_airports)
#      99 df_airports.drop(df_airports.columns[1], axis=1, inplace=True)
# --> 100 df_airports.to_json("airports.json", orient='records')
#     101 print("JSON file generated.")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2422             lines=lines,
#    2423             compression=compression,
# -> 2424             index=index,
#    2425         )
#    2426
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#      76         date_unit=date_unit,
#      77         default_handler=default_handler,
# ---> 78         index=index,
#      79     ).write()
#      80
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in write(self)
#     133             self.date_unit,
#     134             self.date_format == "iso",
# --> 135             self.default_handler,
#     136         )
#     137
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     232             date_unit,
#     233             iso_dates,
# --> 234             default_handler,
#     235         )
#     236
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in _write(self, obj, orient, double_precision, ensure_ascii, date_unit, iso_dates, default_handler)
#     153             date_unit=date_unit,
#     154             iso_dates=iso_dates,
# --> 155             default_handler=default_handler,
#     156         )
#     157
#
# OverflowError: Maximum recursion level reached

# %%
df_airports
# Out:
#      scalerank              type                         name abbrev  \
# 0            9             small                     Sahnewal    LUH
# 1            9               mid                      Solapur    SSE
# 2            9               mid                  Birsa Munda    IXR
# 3            9               mid                        Ahwaz    AWZ
# 4            9  mid and military                      Gwalior    GWL
# ..         ...               ...                          ...    ...
# 886          2             major               Madrid Barajas    MAD
# 887          2             major             Luis Muñoz Marin    SJU
# 888          2             major                      Arlanda    ARN
# 889          2             major         Soekarno-Hatta Int'l    CGK
# 890          2             major  Eleftherios Venizelos Int'l    ATH
#
#      location gps_code iata_code  \
# 0    terminal     VILD       LUH
# 1    terminal     VASL       SSE
# 2    terminal     VERC       IXR
# 3    terminal     OIAW       AWZ
# 4    terminal     VIGR       GWL
# ..        ...      ...       ...
# 886  terminal     LEMD       MAD
# 887  terminal     TJSJ       SJU
# 888  terminal     ESSA       ARN
# 889   parking     WIII       CGK
# 890  terminal     LGAV       ATH
#
#                                              wikipedia  natlscale comments  \
# 0        http://en.wikipedia.org/wiki/Sahnewal_Airport        8.0     None
# 1         http://en.wikipedia.org/wiki/Solapur_Airport        8.0     None
# 2     http://en.wikipedia.org/wiki/Birsa_Munda_Airport        8.0     None
# 3           http://en.wikipedia.org/wiki/Ahwaz_Airport        8.0     None
# 4         http://en.wikipedia.org/wiki/Gwalior_Airport        8.0     None
# ..                                                 ...        ...      ...
# 886  http://en.wikipedia.org/wiki/Madrid_Barajas_In...      150.0     None
# 887  http://en.wikipedia.org/wiki/Luis_Mu%C3%B1oz_M...      150.0     None
# 888  http://en.wikipedia.org/wiki/Stockholm-Arlanda...      150.0     None
# 889  http://en.wikipedia.org/wiki/Soekarno-Hatta_In...      150.0     None
# 890  http://en.wikipedia.org/wiki/Athens_Internatio...      150.0      ???
#
#      ...                                    name_pt               name_ru  \
# 0    ...                                       None                  None
# 1    ...                                       None                  None
# 2    ...                                       None                  None
# 3    ...                                       None                  None
# 4    ...                                       None                  None
# ..   ...                                        ...                   ...
# 886  ...  Aeroporto de Adolfo Suárez Madrid-Barajas               Барахас
# 887  ...   Aeroporto Internacional Luis Muñoz Marin              Каролина
# 888  ...                       Aeroporto de Arlanda     Стокгольм-Арланда
# 889  ...     Aeroporto Internacional Soekarno-Hatta         Сукарно-Хатта
# 890  ...          Aeroporto Internacional de Atenas  Элефтериос Венизелос
#
#                                     name_sv  \
# 0                          Ludhiana Airport
# 1                                      None
# 2                              M. O. Ranchi
# 3               Ahwaz International Airport
# 4                           Gwalior Airport
# ..                                      ...
# 886                Madrid-Barajas flygplats
# 887  Luis Muñoz Marín International Airport
# 888               Stockholm Arlanda Airport
# 889    Soekarno-Hatta International Airport
# 890    Aten-Elefthérios Venizélos flygplats
#
#                                                name_tr  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                     Ahvaz Havalimanı
# 4                                                 None
# ..                                                 ...
# 886             Madrid Barajas Uluslararası Havalimanı
# 887                                               None
# 888                       Stockholm-Arlanda Havalimanı
# 889             Soekarno-Hatta Uluslararası Havalimanı
# 890  Atina Elefterios Venizelos Uluslararası Havali...
#
#                               name_vi              name_zh wdid_score  \
# 0                                None                 None          4
# 1                                None                 None          4
# 2                 Sân bay Birsa Munda                   蘭契          4
# 3                       Sân bay Ahvaz                  阿瓦士          4
# 4                     Sân bay Gwalior                  瓜廖爾          4
# ..                                ...                  ...        ...
# 886    Sân bay quốc tế Madrid Barajas           马德里－巴拉哈斯机场          4
# 887  Sân bay quốc tế Luis Muñoz Marín      路易斯·穆尼奥斯·马林国际机场          4
# 888         Sân bay Stockholm-Arlanda          斯德哥爾摩－阿蘭達機場          4
# 889    Sân bay quốc tế Soekarno-Hatta           蘇加諾－哈達國際機場          4
# 890            Sân bay quốc tế Athena  雅典埃莱夫塞里奥斯·韦尼泽洛斯国际机场          2
#
#           ne_id                    geometry  \
# 0    1159113785   POINT (75.95707 30.85036)
# 1    1159113803   POINT (75.93306 17.62542)
# 2    1159113831   POINT (85.32360 23.31772)
# 3    1159113845   POINT (48.74711 31.34316)
# 4    1159113863   POINT (78.21722 26.28549)
# ..          ...                         ...
# 886  1159127851   POINT (-3.56903 40.46813)
# 887  1159127861  POINT (-66.00423 18.43808)
# 888  1159127877   POINT (17.93073 59.65112)
# 889  1159127891  POINT (106.65430 -6.12660)
# 890  1159127903   POINT (23.94712 37.93623)
#
#                                                geoJSON
# 0    {'type': 'Point', 'coordinates': [75.957072240...
# 1    {'type': 'Point', 'coordinates': [75.933059771...
# 2    {'type': 'Point', 'coordinates': [85.323597036...
# 3    {'type': 'Point', 'coordinates': [48.747106543...
# 4    {'type': 'Point', 'coordinates': [78.217218654...
# ..                                                 ...
# 886  {'type': 'Point', 'coordinates': [-3.569026654...
# 887  {'type': 'Point', 'coordinates': [-66.00422997...
# 888  {'type': 'Point', 'coordinates': [17.930729901...
# 889  {'type': 'Point', 'coordinates': [106.65429615...
# 890  {'type': 'Point', 'coordinates': [23.947116055...
#
# [891 rows x 36 columns]
