# %%
import pandas as pd
import geopandas as gpd

df_master = pd.read_csv("./output/master_dataFrame.csv")
df_tech = pd.read_csv("./output/master_dataFrame.csv")
df_old = pd.read_csv("./output/master_dataFrame.csv")

#Import airports

gdf_airports = gpd.read_file("./Input/ne_10m_airports/ne_10m_airports.shp")

# %%
#Convert df in geoDataFrame

def df_to_gdf(dataframe):
    gdf = gpd.GeoDataFrame(dataframe, geometry=gpd.points_from_xy(dataframe.longitude, dataframe.latitude))
    gdf.crs = {'init' :'epsg:4326'}
    gdf.reset_index(drop=True, inplace=True)
    return gdf

gdf_master = df_to_gdf(df_master)
gdf_tech = df_to_gdf(df_tech)
gdf_old = df_to_gdf(df_old)

# %%
df_final = df_master.copy()

# %%
gdf_airports
# Out:
#      scalerank featurecla              type                         name  \
# 0            9    Airport             small                     Sahnewal
# 1            9    Airport               mid                      Solapur
# 2            9    Airport               mid                  Birsa Munda
# 3            9    Airport               mid                        Ahwaz
# 4            9    Airport  mid and military                      Gwalior
# ..         ...        ...               ...                          ...
# 886          2    Airport             major               Madrid Barajas
# 887          2    Airport             major             Luis Muñoz Marin
# 888          2    Airport             major                      Arlanda
# 889          2    Airport             major         Soekarno-Hatta Int'l
# 890          2    Airport             major  Eleftherios Venizelos Int'l
#
#     abbrev  location gps_code iata_code  \
# 0      LUH  terminal     VILD       LUH
# ...

# %%
# haversine((gdf_master.geometry[0].x, gdf_master.geometry[0].y), (gdf_airports.geometry[0].x, gdf_airports.geometry[0].y))
# gdf_airports.geometry[0].x

# %%
# def col_col_dist(coord_col_origin, coord_col_destination):
#     return [min(row_col_dist(e, coord_col_destination)) if row_col_dist(e, coord_col_destination) else "No airports near" for e in coord_col_origin]
                       
# def row_col_dist(coord_row, coord_col):
#     a = [haversine((coord_row.x, coord_row.y), (f.x, f.y)) for f in coord_col if (haversine((coord_row.x, coord_row.y), (f.x, f.y)) < 20)]
#     return a

# # b = col_col_dist(gdf_master.geometry, gdf_airports.geometry)
# b = col_col_dist(gdf_master.geometry, gdf_airports.geometry)
# b

# %%
from numpy import cos, sin, arcsin, sqrt
from math import radians
def haversine(lon1, lat1, lon2, lat2):
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * arcsin(sqrt(a)) 
    km = 6367 * c
    return km

haversine(gdf_master.geometry[0].x, gdf_master.geometry[0].y, gdf_airports.geometry.x[0], gdf_airports.geometry[0].y)
# Out:
# 12174.43666673078

# %%
distances = []
min_distances = []

def minDistances(origin_gdf, destination_gdf):
    for f in origin_gdf.geometry:
        for e in destination_gdf.geometry:
            distances.append((haversine(f.x, f.y, e.x, e.y), e))
        min_distances.append(min(distances, key=lambda p: p[0]))
    return min_distances

minDistances(gdf_master, gdf_airports)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-36dbcd1a4f93> in <module>
#       9     return min_distances
#      10
# ---> 11 minDistances(gdf_master, gdf_airports)
#
# <ipython-input-17-36dbcd1a4f93> in minDistances(origin_gdf, destination_gdf)
#       5     for f in origin_gdf.geometry:
#       6         for e in destination_gdf.geometry:
# ----> 7             distances.append((haversine(f.x, f.y, e.x, e.y), e))
#       8         min_distances.append(min(distances, key=lambda p: p[0]))
#       9     return min_distances
#
# ~/.local/lib/python3.6/site-packages/shapely/geometry/point.py in x(self)
#      51     # Coordinate getters and setters
#      52
# ---> 53     @property
#      54     def x(self):
#      55         """Return x coordinate."""
#
# KeyboardInterrupt:

# %%
gdf_airports.geometry
# Out:
# 0       POINT (75.95707 30.85036)
# 1       POINT (75.93306 17.62542)
# 2       POINT (85.32360 23.31772)
# 3       POINT (48.74711 31.34316)
# 4       POINT (78.21722 26.28549)
#                   ...
# 886     POINT (-3.56903 40.46813)
# 887    POINT (-66.00423 18.43808)
# 888     POINT (17.93073 59.65112)
# 889    POINT (106.65430 -6.12660)
# 890     POINT (23.94712 37.93623)
# Name: geometry, Length: 891, dtype: geometry
